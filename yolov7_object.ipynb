# %% [markdown]
# <a href="https://colab.research.google.com/github/tranquockhang758/Arduino-Invt-React-NodeJS/blob/master/yolov7_object.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Clone source code YOLOv7 về thư mục Yolov7_train
# %cd /content/drive/MyDrive/yolov7_object
# !git clone https://github.com/augmentedstartups/yolov7.git #https://github.com/WongKinYiu/yolov7

# %%
# Cài đặt các thư viện cần thiết để train YOLOv7
# %cd /content/drive/MyDrive/yolov7_object/yolov7
# !pip install -r requirements.txt

# %%
# Tải weight pretrain về để nhận diện thử
# %cd
# Nhận diện thử với weight pretrain
# %cd /content/drive/MyDrive/yolov7_object/yolov7
# !mkdir pretrain
# %cd pretrain
# !wget https://github.com/WongKinYiu/yolov7/releases/download/v0.1/yolov7.pt

# %%
# Tải ảnh sample từ internet
# %cd /content/drive/MyDrive/yolov7_object/yolov7
# !mkdir test_images
# %cd test_images
# !wget https://cdn.theculturetrip.com/wp-content/uploads/2017/11/15271255494_fcc90d3f9b_k.jpg
# !wget https://cdnimgen.vietnamplus.vn/t620/uploaded/wbxx/2020_05_13/85896_3585300525545474_a1.jpg
# !wget https://media-cdn-v2.laodong.vn/Storage/NewsPortal/2020/4/22/800234/Chay-Pho-Co-9.jpg
# !wget https://i-vnexpress.vnecdn.net/2019/03/23/chay-1-3737-1553317413.jpg

# %%
#Tải ảnh mèo
# %cd /content/drive/MyDrive/yolov7_object/yolov7/test_images/
# !wget https://nupet.vn/wp-content/uploads/2023/10/hinh-nen-ngo-nghinh-anh-meo-cute-nupet-new-5.jpg

# %%
# Nhận diện thử với weight pretrain
# %cd /content/drive/MyDrive/yolov7_object/yolov7
# !python detect.py --weights pretrain/yolov7.pt --source test_images/15271255494_fcc90d3f9b_k.jpg

# %%
# Giải nén dữ liệu đê train model
# %cd /content/drive/MyDrive/yolov7_object
# !mkdir train_data
# %cd train_data
# !mkdir train
# !mkdir train/images
# !mkdir train/labels
# Out:
# /content/drive/MyDrive/yolov7_object
# /content/drive/MyDrive/yolov7_object/train_data

# %%
# Giải nén dữ liệu đê train model
# %cd /content/drive/MyDrive/yolov7_object
# !mkdir train_data
# %cd train_data
# !unzip ../catdata.zip

# %%
# %cd /content/drive/MyDrive/yolov7_object/train_data

# !mv *.jpg train/images
# !mv *.txt train/labels

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# Tổ chức lại thư mục train. Lý do: Vì YOLOv7 yêu cầu
# train
#   - images
#   - labels
# test
#   - images
#   - labels

# %cd /content/drive/MyDrive/yolov7_object/train_data
# !mkdir train
# !mkdir train/images
# !mkdir train/labels
# !mv *.jpg train/images
# !mv *.txt train/labels
# Out:
# /content/drive/MyDrive/yolov7_object/train_data

# %%
# Khai báo 1 file yaml để YOLOv7 biết:
# - Đường dẫn đến thư mục train, test (nếu có, nếu không thì dùng luôn đường dẫn đến train)
# - Số lượng class qua biến nc (number of class)
# - Tên của các class
# %cd /content/drive/MyDrive/yolov7_object/yolov7
# !rm data/mydataset.yaml # nếu có
# !echo 'train: ../train_data/train' >> data/mydataset.yaml
# !echo 'val: ../train_data/train' >> data/mydataset.yaml
# !echo 'nc: 1' >> data/mydataset.yaml
# !echo "names: ['cat']" >> data/mydataset.yaml

# %%
# Train model YOLOv7 với dữ liệu cat
# %cd /content/drive/MyDrive/yolov7_object/yolov7
# !python train.py --batch 16 --cfg cfg/training/yolov7.yaml --epochs 500 --data data/mydataset.yaml --weights 'pretrain/yolov7.pt'
# Out:
# /content/drive/MyDrive/yolov7_object/yolov7
# 2024-04-06 15:09:22.627422: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-04-06 15:09:22.627480: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-04-06 15:09:22.628840: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-04-06 15:09:22.636376: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# ...

# %%
#Nhận diện ảnh mèo
# Train model YOLOv7 với dữ liệu cat
# %cd /content/drive/MyDrive/yolov7_object/yolov7
# !python detect.py --weights '/content/drive/MyDrive/yolov7_object/yolov7/runs/train/exp9/weights/last.pt' --source test_images/hinh-nen-ngo-nghinh-anh-meo-cute-nupet-new-5.jpg
# Out:
# /content/drive/MyDrive/yolov7_object/yolov7
# Namespace(weights=['/content/drive/MyDrive/yolov7_object/yolov7/runs/train/exp9/weights/last.pt'], source='test_images/hinh-nen-ngo-nghinh-anh-meo-cute-nupet-new-5.jpg', img_size=640, conf_thres=0.25, iou_thres=0.45, device='', view_img=False, save_txt=False, save_conf=False, nosave=False, classes=None, agnostic_nms=False, augment=False, update=False, project='runs/detect', name='exp', exist_ok=False, no_trace=False)
# YOLOR 🚀 v0.1-104-g941b94c torch 2.2.1+cu121 CUDA:0 (Tesla V100-SXM2-16GB, 16151.125MB)
#
# Fusing layers...
# RepConv.fuse_repvgg_block
# RepConv.fuse_repvgg_block
# RepConv.fuse_repvgg_block
# IDetect.fuse
# Model Summary: 314 layers, 36481772 parameters, 6194944 gradients
#  Convert model to Traced-model...
#  traced_script_module saved!
#  model is traced!
#
# ...
